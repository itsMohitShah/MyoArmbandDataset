# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
path = r"PreTrainingDataset\Female0\training0\classe_0.dat"
with open(path, 'rb') as f:
    contents = f.read()

# %%
type(contents)
contents
# Out:
# b'
# ...

# %%
import chardet
chardet.detect(contents)
# Out:
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}

# %%
x = contents.decode('utf-16', errors='strict')

# %%
x = np.fromfile(path, dtype="byte")

# %%
x
# Out:
# array([-2, -1, -1, ...,  0, -2, -1], dtype=int8)

# %%
plt.plot(x, linewidth=0.4)
plt.show()

"""
According to page 5 of research paper, When the signal comes form an array of electrodes, these examples can naturally be structured as Time x Spatial x Frequency 
"""
# Out:
# '\nAccording to page 5 of research paper, When the signal comes form an array of electrodes, these examples can naturally be structured as Time x Spatial x Frequency \n'

# %%
# np.shape(x)[0]
len(x)
# Out:
# 15968

# %%
print(4*8*14)
print(15968/448)

print(16000/200)
# 5 seconds
# SPlit into 8 channels
# Out:
# 448
# 35.642857142857146
# 80.0

# %% [markdown]
# # Trial

# %%
fourierTransform = (np.fft.fft(x))/len(x)

# %%
plt.plot(fourierTransform, linewidth=0.4)
plt.show()
# Out:
# d:\Users\mohit\anaconda3\envs\env1\lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
